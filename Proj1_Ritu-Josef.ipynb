# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = 20,10
import numpy as np
import glob
from scipy import stats

# %%
cd CSVs
# Out:
# /Users/jseemayer/Documents/Me/Metis/mta-project-1/CSVs

# %% [markdown]
# #### Load Data

# %%
extension = 'txt'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
data = pd.concat([pd.read_csv(f) for f in all_filenames ])
data
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/11/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/11/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/11/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/11/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/11/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 206852  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206853  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206854  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206855  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
# 206856  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  05/03/2019
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  7053483
# 1       04:00:00  REGULAR  7053511
# 2       08:00:00  REGULAR  7053534
# 3       12:00:00  REGULAR  7053618
# 4       16:00:00  REGULAR  7053841
# ...          ...      ...      ...
# 206852  05:00:00  REGULAR     5554
# 206853  09:00:00  REGULAR     5554
# 206854  13:00:00  REGULAR     5554
# 206855  17:00:00  REGULAR     5554
# 206856  21:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2390505
# 1                                                 2390508
# 2                                                 2390536
# 3                                                 2390596
# 4                                                 2390655
# ...                                                   ...
# 206852                                                376
# 206853                                                376
# 206854                                                376
# 206855                                                376
# 206856                                                376
#
# [2250808 rows x 11 columns]

# %% [markdown]
# ### Clean Data

# %% [markdown]
# remove spaces from column names

# %%
data.columns = data.columns.str.replace(' ', '')

# %% [markdown]
# add Date_Time column

# %%
data['Date_Time'] = pd.to_datetime(data['DATE'], cache=True) + pd.to_timedelta(data['TIME'])

# %% [markdown]
# Add Turnstile (Combining SCP,C/A, Station and Unit) and Weekday column

# %%
data['Turnstile'] = data['C/A'] + data['UNIT'] + data['SCP'] + data['STATION']
data['DATE'] = pd.to_datetime(data['DATE'], cache=True)
data['Week_Day'] = data['DATE'].dt.day_name()

# %% [markdown]
# #### Find total traffic

# %% [markdown]
# Add shifted columns to show previous entries and exits

# %%
#All turnstiles have cumulative counts, previous data needs to be subtraced from current data 
#to find total entries/exits
grouped_time=data
grouped_time["PREV_TIME"] = data.groupby(["Turnstile"]).TIME.shift(1)
grouped_time["PREV_EXITS"] = data.groupby(["Turnstile"]).EXITS.shift(1)
grouped_time["PREV_ENTRIES"] = data.groupby(["Turnstile"]).ENTRIES.shift(1)
#grouped_time.head()

# %%
#drop first row of each turnstile b/c of shift down
grouped_time.dropna(subset=["PREV_ENTRIES"], axis=0, inplace=True)

# %% [markdown]
# Remove counter errors from total entries/exits that occur from counters resetting

# %%
def get_daily_counts_exits(row, max_counter):
    counter_ex = row["EXITS"] - row["PREV_EXITS"]
    if counter_ex < 0:
        # Maybe counter is reversed?
        counter_ex = -counter_ex
    if counter_ex > max_counter:
        # Maybe counter was reset to 0? 
        #print(row["EXITS"], row["PREV_EXITS"])
        counter_ex = min(row["EXITS"], row["PREV_EXITS"])
    if counter_ex > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter_ex

def get_daily_counts_entries(row, max_counter):
    counter_ent = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter_ent < 0:
        # Maybe counter is reversed?
        counter_ent = -counter_ent
    if counter_ent > max_counter:
        # Maybe counter was reset to 0? 
        #print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter_ent = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter_ent > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter_ent


# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!

# %%
grouped_time["TOTAL_ENTRIES"] = grouped_time.apply(get_daily_counts_entries, axis=1, max_counter=100000)
grouped_time["TOTAL_EXITS"] = grouped_time.apply(get_daily_counts_exits, axis=1, max_counter=100000)
#grouped_time["TOTAL_EXITS"] = grouped_time.apply(get_daily_counts, axis=1, max_counter=1000000)

# %%
grouped_time = grouped_time[(np.abs(stats.zscore(grouped_time["TOTAL_ENTRIES"])) < 3)] #filtering
grouped_time = grouped_time[(np.abs(stats.zscore(grouped_time["TOTAL_EXITS"])) < 3)] #filtering
grouped_time["TOTAL_TRAFFIC"] = grouped_time["TOTAL_EXITS"] + grouped_time["TOTAL_ENTRIES"]
grouped_time.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-05-11  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-05-11  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-05-11  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-05-11  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-05-11  20:00:00
#
#       DESC  ENTRIES    EXITS           Date_Time              Turnstile  \
# 1  REGULAR  7053511  2390508 2019-05-11 04:00:00  A002R05102-00-0059 ST
# 2  REGULAR  7053534  2390536 2019-05-11 08:00:00  A002R05102-00-0059 ST
# 3  REGULAR  7053618  2390596 2019-05-11 12:00:00  A002R05102-00-0059 ST
# 4  REGULAR  7053841  2390655 2019-05-11 16:00:00  A002R05102-00-0059 ST
# 5  REGULAR  7054133  2390702 2019-05-11 20:00:00  A002R05102-00-0059 ST
#
#    Week_Day PREV_TIME  PREV_EXITS  PREV_ENTRIES  TOTAL_ENTRIES  TOTAL_EXITS  \
# 1  Saturday  00:00:00   2390505.0     7053483.0           28.0          3.0
# 2  Saturday  04:00:00   2390508.0     7053511.0           23.0         28.0
# 3  Saturday  08:00:00   2390536.0     7053534.0           84.0         60.0
# 4  Saturday  12:00:00   2390596.0     7053618.0          223.0         59.0
# 5  Saturday  16:00:00   2390655.0     7053841.0          292.0         47.0
#
#    TOTAL_TRAFFIC
# 1           31.0
# 2           51.0
# 3          144.0
# 4          282.0
# 5          339.0

# %% [markdown]
# remove total traffic outliers that are 3 sigmas from mean

# %%
grouped_time = grouped_time[(np.abs(stats.zscore(grouped_time['TOTAL_TRAFFIC'])) < 3)] #filtering

# %% [markdown]
# drop uneeded columns

# %%
grouped_time.columns = grouped_time.columns.str.replace(' ', '')
grouped_time.drop(['C/A','UNIT','SCP','LINENAME', 'ENTRIES', 'EXITS', 'PREV_TIME', 'PREV_ENTRIES', 'PREV_EXITS','TOTAL_ENTRIES','TOTAL_EXITS',], axis=1, inplace = True)
#grouped_time.head(100)
#grouped_time.shape

# %%
grouped_time.head(100)
# Out:
#     STATION DIVISION       DATE      TIME     DESC           Date_Time  \
# 1     59 ST      BMT 2019-05-11  04:00:00  REGULAR 2019-05-11 04:00:00
# 2     59 ST      BMT 2019-05-11  08:00:00  REGULAR 2019-05-11 08:00:00
# 3     59 ST      BMT 2019-05-11  12:00:00  REGULAR 2019-05-11 12:00:00
# 4     59 ST      BMT 2019-05-11  16:00:00  REGULAR 2019-05-11 16:00:00
# 5     59 ST      BMT 2019-05-11  20:00:00  REGULAR 2019-05-11 20:00:00
# ..      ...      ...        ...       ...      ...                 ...
# 98    59 ST      BMT 2019-05-13  00:00:00  REGULAR 2019-05-13 00:00:00
# 99    59 ST      BMT 2019-05-13  04:00:00  REGULAR 2019-05-13 04:00:00
# 100   59 ST      BMT 2019-05-13  08:00:00  REGULAR 2019-05-13 08:00:00
# 101   59 ST      BMT 2019-05-13  08:30:55  REGULAR 2019-05-13 08:30:55
# 102   59 ST      BMT 2019-05-13  12:00:00  REGULAR 2019-05-13 12:00:00
#
#                  Turnstile  Week_Day  TOTAL_TRAFFIC
# 1    A002R05102-00-0059 ST  Saturday           31.0
# 2    A002R05102-00-0059 ST  Saturday           51.0
# 3    A002R05102-00-0059 ST  Saturday          144.0
# 4    A002R05102-00-0059 ST  Saturday          282.0
# 5    A002R05102-00-0059 ST  Saturday          339.0
# ..                     ...       ...            ...
# 98   A002R05102-03-0059 ST    Monday          144.0
# 99   A002R05102-03-0059 ST    Monday            9.0
# 100  A002R05102-03-0059 ST    Monday          281.0
# 101  A002R05102-03-0059 ST    Monday          119.0
# 102  A002R05102-03-0059 ST    Monday          627.0
#
# [100 rows x 9 columns]

# %%
grouped_day = data.groupby(['DATE','Turnstile','STATION'], as_index=False).agg({'ENTRIES': ['min', 'max'], 'EXITS': ['min', 'max']})
#grouped = data.groupby(['STATION','DATE']).agg({'ENTRIES': ['min', 'max'], 'EXITS': ['min', 'max']})
#grouped = grouped.set_index('STATION')
#grouped.head()

# %%
#grouped_day.head()

# %%
#grouped.columns = [ 'Station', 'Date', 'ENTRIES_MIN', 'ENTRIES_MAX', 'EXITS_MIN', 'EXITS_MAX']
grouped_day.columns = [ 'Date', 'Turnstile', 'Station','ENTRIES_MIN', 'ENTRIES_MAX', 'EXITS_MIN', 'EXITS_MAX']
#grouped.columns = ['ENTRIES_MIN', 'ENTRIES_MAX', 'EXITS_MIN', 'EXITS_MAX']
#grouped.dtypes

# %%
grouped_day.head()
# Out:
#         Date              Turnstile Station  ENTRIES_MIN  ENTRIES_MAX  \
# 0 2019-03-30  A002R05102-00-0059 ST   59 ST      6999064      6999796
# 1 2019-03-30  A002R05102-00-0159 ST   59 ST      6238770      6239372
# 2 2019-03-30  A002R05102-03-0059 ST   59 ST      1211476      1211761
# 3 2019-03-30  A002R05102-03-0159 ST   59 ST      1049198      1049913
# 4 2019-03-30  A002R05102-03-0259 ST   59 ST      6132784      6133502
#
#    EXITS_MIN  EXITS_MAX
# 0    2373568    2373837
# 1    1399138    1399289
# 2    4553166    4554337
# 3    1621305    1622549
# 4    8279411    8280248

# %% [markdown]
# Find total entries exits, and traffic

# %%
grouped_day['Total_Entries'] = grouped_day['ENTRIES_MAX'] - grouped_day['ENTRIES_MIN']
grouped_day['Total_Exits'] = grouped_day['EXITS_MAX'] - grouped_day['EXITS_MIN']
grouped_day['Total_Traffic'] = grouped_day['Total_Exits'] + grouped_day['Total_Entries']
#grouped_day.head()

# %%
grouped_day.drop(['ENTRIES_MIN','ENTRIES_MAX','EXITS_MIN','EXITS_MAX', 'Total_Entries', 'Total_Exits', ], axis=1,inplace = True)

# %% [markdown]
# Removing Outlier data from Total_traffic column (Removing anything outside 3 sigma)

# %%
grouped_day = grouped_day[(np.abs(stats.zscore(grouped_day['Total_Traffic'])) < 3)] #filtering

# %%
#grouped_time[grouped_time["ENTRIES"] < grouped_time["PREV_ENTRIES"]].head()

# %%
#grouped_time = data.sort_values(['Date_Time']).groupby(['Turnstile','STATION','DIVISION','Date_Time'],as_index = False).agg({'ENTRIES': ['diff'], 'EXITS': ['diff']})

# %%
#grouped_time = data
#grouped_time.sort_values(['Turnstile','Date_Time'],inplace = True)
#grouped_time.head(5)
#entry_vals = grouped_time['ENTRIES'].values
#exit_vals = grouped_time['EXITS'].values
#len(entry)
#len (entry_vals[:-1])
#len (entry_vals[1:])
#diffs_entry = entry_vals[1:] - entry_vals[:-1]
#diffs_exit = exit_vals[1:] - exit_vals[:-1]
#diffs_entry = np.append(diffs_entry,0)
#diffs_exit = np.append(diffs_exit,0)
#grouped_time['diffs_entry'] = grouped_time.groupby(['Turnstile'])['ENTRIES'].diff()
#grouped_time['diffs_exit'] = grouped_time.groupby(['Turnstile'])['EXITS'].diff()
#mask = !((grouped_time['diffs_entry'] == 0) && (grouped_time['diffs_exit'] == 0))
#mask =   grouped_time['diffs_entry'] == 0
#grouped_time = grouped_time[grouped_time['diffs_entry'] ]
#grouped_time['diffs_entry'] = grouped_time.rolling_apply(data['ENTRIES'], 2, lambda x: x[1] - x[0])
#grouped_time['diffs_exit'] = grouped_time.rolling_apply(data['EXITS'], 2, lambda x: x[1] - x[0])
#grouped_time.head()
#mask
#grouped_time.head()

# %%
#entry_vals = grouped_time['ENTRIES'].values
#entry_vals[1:]

# %%
grouped_day['Date'] = pd.to_datetime(grouped_day['Date'], cache=True)
grouped_day['Week_Day'] = grouped_day['Date'].dt.day_name()

# %%
grouped_day.head()
# Out:
#         Date              Turnstile Station  Total_Traffic  Week_Day
# 0 2019-03-30  A002R05102-00-0059 ST   59 ST           1001  Saturday
# 1 2019-03-30  A002R05102-00-0159 ST   59 ST            753  Saturday
# 2 2019-03-30  A002R05102-03-0059 ST   59 ST           1456  Saturday
# 3 2019-03-30  A002R05102-03-0159 ST   59 ST           1959  Saturday
# 4 2019-03-30  A002R05102-03-0259 ST   59 ST           1555  Saturday

# %% [markdown]
# #### Combine data

# %% [markdown]
# ### Finding top 10 visited stations

# %%
Total_ridership = grouped_day.groupby(['Station']).Total_Traffic.sum().reset_index()

# %%
Total_ridership.sort_values(by=['Total_Traffic'],inplace = True, ascending = False)

# %%
Total_ridership = grouped_time.groupby(['STATION']).TOTAL_TRAFFIC.sum().reset_index()
Total_ridership.sort_values(by=['TOTAL_TRAFFIC'],inplace = True, ascending = False)

# %%
Row_list =[] 
indices = []
  
# Iterate over each row 
for index, rows in Total_ridership[:10].iterrows(): 
    # Create list for the current row 
#    my_list =[rows.STATION, rows.Total_Traffic] 
    my_list =rows.TOTAL_TRAFFIC
    station_list = rows.STATION
    # append the list to the final list 
    Row_list.append(my_list) 
    indices.append(station_list)
Total_ridership.head(20)
# Out:
#              STATION  TOTAL_TRAFFIC
# 61    34 ST-PENN STA     20435879.0
# 232  GRD CNTRL-42 ST     15374876.0
# 59   34 ST-HERALD SQ     13653317.0
# 46             23 ST     12962556.0
# 352   TIMES SQ-42 ST     12751254.0
# 14    14 ST-UNION SQ     12535312.0
# 225        FULTON ST     11697505.0
# 68   42 ST-PORT AUTH     11668502.0
# 110            86 ST     10749092.0
# 9             125 ST      9755552.0
# 172         CANAL ST      9288378.0
# 86    59 ST COLUMBUS      8551470.0
# 85             59 ST      8132852.0
# 13             14 ST      7774153.0
# 115            96 ST      7673025.0
# 72    47-50 STS ROCK      7585891.0
# 179      CHAMBERS ST      7003427.0
# 216    FLUSHING-MAIN      6563771.0
# 314     PATH NEW WTC      6320618.0
# 97             72 ST      6315227.0

# %%
Row_list =[] 
indices = []
  
# Iterate over each row 
for index, rows in Total_ridership[:10].iterrows(): 
    # Create list for the current row 
#    my_list =[rows.STATION, rows.Total_Traffic] 
    my_list =rows.TOTAL_TRAFFIC 
    station_list = rows.STATION
    # append the list to the final list 
    Row_list.append(my_list) 
    indices.append(station_list)
Total_ridership.head(20)
# Out:
#              STATION  TOTAL_TRAFFIC
# 61    34 ST-PENN STA     20435879.0
# 232  GRD CNTRL-42 ST     15374876.0
# 59   34 ST-HERALD SQ     13653317.0
# 46             23 ST     12962556.0
# 352   TIMES SQ-42 ST     12751254.0
# 14    14 ST-UNION SQ     12535312.0
# 225        FULTON ST     11697505.0
# 68   42 ST-PORT AUTH     11668502.0
# 110            86 ST     10749092.0
# 9             125 ST      9755552.0
# 172         CANAL ST      9288378.0
# 86    59 ST COLUMBUS      8551470.0
# 85             59 ST      8132852.0
# 13             14 ST      7774153.0
# 115            96 ST      7673025.0
# 72    47-50 STS ROCK      7585891.0
# 179      CHAMBERS ST      7003427.0
# 216    FLUSHING-MAIN      6563771.0
# 314     PATH NEW WTC      6320618.0
# 97             72 ST      6315227.0

# %%
plt.ylim(10000000,22000000)
plt.xlabel("Station")
plt.ylabel("Total Traffic")
plt.title("Total traffic for the period for top 10 busiest stations")
plt.bar(indices, Row_list)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# Top 10 Busy Stations, We will focus on top5 of these.

# %%
indices
# Out:
# ['34 ST-PENN STA',
#  'GRD CNTRL-42 ST',
#  '34 ST-HERALD SQ',
#  '23 ST',
#  'TIMES SQ-42 ST',
#  '14 ST-UNION SQ',
#  'FULTON ST',
#  '42 ST-PORT AUTH',
#  '86 ST',
#  '125 ST']

# %% [markdown]
# ### Find high traffic days

# %%
Total_Weekly_ridership = grouped_time.groupby(['Week_Day']).TOTAL_TRAFFIC.sum().reset_index()
#Total_Weekly_ridership = grouped_day.groupby(['Week_Day']).Total_Traffic.mean().reset_index()
Total_Weekly_ridership.sort_values(by=['TOTAL_TRAFFIC'],inplace = True, ascending = False)
Total_Weekly_ridership.head()
# Out:
#     Week_Day  TOTAL_TRAFFIC
# 6  Wednesday    116702638.0
# 4   Thursday    116094534.0
# 5    Tuesday    113661501.0
# 0     Friday    112009149.0
# 1     Monday    103251369.0

# %%
#plt.ylim(1610000000000,1620000000000)
plt.ylim(40000000,130000000)
daysoweek = plt.bar(Total_Weekly_ridership['Week_Day'], Total_Weekly_ridership['TOTAL_TRAFFIC'])
for i in range(5):
    daysoweek[i].set_color('#2a3990')
daysoweek[5].set_color('#f06292')
daysoweek[6].set_color('#f06292')

# %% [markdown]
# Based on this it seems like weekends see much less traffic compared to weekdays. So WWTF should focus more on weekdays

# %%
Top5 = Total_ridership['STATION'][0:5].tolist()
Top5_stations = grouped_time[grouped_time['STATION'].isin(Top5)]
Top5_station_weekly = Top5_stations.groupby(['STATION','Week_Day']).TOTAL_TRAFFIC.sum().reset_index()
Top5_station_Daily = Top5_stations.groupby(['STATION','DATE']).TOTAL_TRAFFIC.sum().reset_index()
#Top5_station_weekly = Top5_stations.groupby(['Station','Week_Day']).Total_Traffic.mean().reset_index()

# %% [markdown]
# #### Weekly Plot for Top5 stations

# %%
for stations in Top5:
    station = Top5_station_weekly[Top5_station_weekly['STATION'] == stations]
#    print(station)
    plt.plot(station['Week_Day'],station['TOTAL_TRAFFIC'],label = stations)
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
plt.legend()
plt.show()

# %% [markdown]
# Looking at the plot seems like top5 stations are also showing a dip on weekends, but PATH NEW WTC station is oblitrating seeing the trend properly. This needs to be investigated further. Also, to see the trend for rest of the station we will do another plot removing the data for PATH NEW WTC

# %%
for stations in Top5:
    if stations != "PATH NEW WTC" :
        station = Top5_station_weekly[Top5_station_weekly['STATION'] == stations]
#    print(station)
        plt.plot(station['Week_Day'],station['TOTAL_TRAFFIC'],label = stations)
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
plt.legend()
plt.show()

# %% [markdown]
# This is also showing the dip in weekend more clearly. But GRD CNTRL-42 ST shows peak on thursday - which needs to be investigated.

# %%
for stations in Top5:
    station = Top5_station_Daily[Top5_station_Daily['STATION'] == stations]
#    print(station)
    plt.plot(station['DATE'],station['TOTAL_TRAFFIC'],label = stations)
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
plt.legend()
plt.show()

# %% [markdown]
# This plot is also showing some abnormal values for some of the days for PATH NEW WTC. Two of these dates are looking on thursdays. We will look at rest of the stations removing PATH NEW WTC

# %%
for stations in Top5:
    if stations != "PATH NEW WTC" :
        station = Top5_station_Daily[Top5_station_Daily['STATION'] == stations]
#    print(station)
        plt.plot(station['DATE'],station['TOTAL_TRAFFIC'],label = stations)
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
plt.legend()
plt.show()

# %% [markdown]
# This plot also seems to have some outliers. But In general trend is clear Traffic takes a dip on weekends and remains kind of static on weekdays

# %% [markdown]
# ### Find peak hours

# %%
Top10 = Total_ridership['STATION'][0:10].tolist()
Top10_stations = grouped_time[grouped_time['STATION'].isin(Top10)]
Top10_stations.head()
#Top10
Top10_station_hourly = Top10_stations.groupby(['STATION','TIME']).TOTAL_TRAFFIC.sum().reset_index()
Top10_station_hourly.head()
#Top5_station_Daily = Top5_stations.groupby(['Station','Date']).Total_Traffic.sum().reset_index()
# Out:
#   STATION      TIME  TOTAL_TRAFFIC
# 0  125 ST  00:00:00       551016.0
# 1  125 ST  01:00:00       407250.0
# 2  125 ST  04:00:00       129323.0
# 3  125 ST  05:00:00       102593.0
# 4  125 ST  05:00:01          622.0

# %%
Top10_station_hourly.dtypes
# Out:
# STATION           object
# TIME              object
# TOTAL_TRAFFIC    float64
# dtype: object

# %%
#Top10_station_hourly['TIME'].dtype
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
for stations in Top10:
     station = Top10_station_hourly[Top10_station_hourly['STATION'] == stations]
#    print(station)
     fig, ax = plt.subplots()
     ax.plot(station['TIME'],station['TOTAL_TRAFFIC'],label = stations)
     ax.set_xticks(ax.get_xticks()[::5])
     plt.xticks(rotation = 'vertical')
     plt.legend()   
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
#ax.set_xticks(ax.get_xticks()[::10])
#plt.legend()
plt.show()

# %%
wtc_station = grouped_time[grouped_time['STATION'] == "PATH NEW WTC"]
wtc_station_hourly = wtc_station.groupby(['STATION','TIME']).TOTAL_TRAFFIC.sum().reset_index()
fig, ax = plt.subplots()
ax.plot(wtc_station_hourly['TIME'],wtc_station_hourly['TOTAL_TRAFFIC'],label = "PATH NEW WTC")
ax.set_xticks(ax.get_xticks()[::100])
plt.xticks(rotation = 'vertical')
plt.legend()
plt.show()

# %% [markdown]
# ### Find high traffic areas for games

# %% [markdown]
# ### Find top stations in each area code

# %%
loc_data = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/Stations.csv')
print(loc_data.Borough.unique())
loc_data.tail()
# Out:
# ['Q' 'M' 'Bk' 'Bx' 'SI']
#      Station ID  Complex ID GTFS Stop ID Division           Line  \
# 491         517         517          S15      SIR  Staten Island
# 492         518         518          S14      SIR  Staten Island
# 493         519         519          S13      SIR  Staten Island
# 494         522         522          S09      SIR  Staten Island
# 495         523         523          S11      SIR  Staten Island
#
#            Stop Name Borough Daytime Routes   Structure  GTFS Latitude  \
# 491     Prince's Bay      SI            SIR    Open Cut      40.525507
# 492  Pleasant Plains      SI            SIR  Embankment      40.522410
# 493  Richmond Valley      SI            SIR    Open Cut      40.519631
# 494      Tottenville      SI            SIR    At Grade      40.512764
# 495      Arthur Kill      SI            SIR    At Grade      40.516578
#
#      GTFS Longitude North Direction Label South Direction Label  ADA ADA Notes
# 491      -74.200064             St George           Tottenville    0       NaN
# 492      -74.217847             St George           Tottenville    0       NaN
# 493      -74.229141             St George           Tottenville    0       NaN
# 494      -74.251961             St George                   NaN    1       NaN
# 495      -74.242096             St George           Tottenville    1       NaN

# %%
grouped_time['FIRST'] =  grouped_time.TIME.astype(str).str[:2].astype(int)
grouped_time.head(20)
# Out:
#    STATION DIVISION       DATE      TIME     DESC           Date_Time  \
# 1    59 ST      BMT 2019-05-11  04:00:00  REGULAR 2019-05-11 04:00:00
# 2    59 ST      BMT 2019-05-11  08:00:00  REGULAR 2019-05-11 08:00:00
# 3    59 ST      BMT 2019-05-11  12:00:00  REGULAR 2019-05-11 12:00:00
# 4    59 ST      BMT 2019-05-11  16:00:00  REGULAR 2019-05-11 16:00:00
# 5    59 ST      BMT 2019-05-11  20:00:00  REGULAR 2019-05-11 20:00:00
# 6    59 ST      BMT 2019-05-12  00:00:00  REGULAR 2019-05-12 00:00:00
# 7    59 ST      BMT 2019-05-12  04:00:00  REGULAR 2019-05-12 04:00:00
# 8    59 ST      BMT 2019-05-12  08:00:00  REGULAR 2019-05-12 08:00:00
# 9    59 ST      BMT 2019-05-12  12:00:00  REGULAR 2019-05-12 12:00:00
# 10   59 ST      BMT 2019-05-12  16:00:00  REGULAR 2019-05-12 16:00:00
# 11   59 ST      BMT 2019-05-12  20:00:00  REGULAR 2019-05-12 20:00:00
# 12   59 ST      BMT 2019-05-13  00:00:00  REGULAR 2019-05-13 00:00:00
# 13   59 ST      BMT 2019-05-13  04:00:00  REGULAR 2019-05-13 04:00:00
# 14   59 ST      BMT 2019-05-13  08:00:00  REGULAR 2019-05-13 08:00:00
# 15   59 ST      BMT 2019-05-13  08:30:55  REGULAR 2019-05-13 08:30:55
# 16   59 ST      BMT 2019-05-13  12:00:00  REGULAR 2019-05-13 12:00:00
# 17   59 ST      BMT 2019-05-13  16:00:00  REGULAR 2019-05-13 16:00:00
# 18   59 ST      BMT 2019-05-13  20:00:00  REGULAR 2019-05-13 20:00:00
# 19   59 ST      BMT 2019-05-14  00:00:00  REGULAR 2019-05-14 00:00:00
# 20   59 ST      BMT 2019-05-14  04:00:00  REGULAR 2019-05-14 04:00:00
#
#                 Turnstile  Week_Day  TOTAL_TRAFFIC  FIRST
# 1   A002R05102-00-0059 ST  Saturday           31.0      4
# 2   A002R05102-00-0059 ST  Saturday           51.0      8
# 3   A002R05102-00-0059 ST  Saturday          144.0     12
# 4   A002R05102-00-0059 ST  Saturday          282.0     16
# 5   A002R05102-00-0059 ST  Saturday          339.0     20
# 6   A002R05102-00-0059 ST    Sunday          182.0      0
# 7   A002R05102-00-0059 ST    Sunday           21.0      4
# 8   A002R05102-00-0059 ST    Sunday           27.0      8
# 9   A002R05102-00-0059 ST    Sunday          115.0     12
# 10  A002R05102-00-0059 ST    Sunday          172.0     16
# 11  A002R05102-00-0059 ST    Sunday          214.0     20
# 12  A002R05102-00-0059 ST    Monday          100.0      0
# 13  A002R05102-00-0059 ST    Monday           12.0      4
# 14  A002R05102-00-0059 ST    Monday          129.0      8
# 15  A002R05102-00-0059 ST    Monday           74.0      8
# 16  A002R05102-00-0059 ST    Monday          328.0     12
# 17  A002R05102-00-0059 ST    Monday          393.0     16
# 18  A002R05102-00-0059 ST    Monday          741.0     20
# 19  A002R05102-00-0059 ST   Tuesday          201.0      0
# 20  A002R05102-00-0059 ST   Tuesday           15.0      4

# %%
def make_time_bins(row):
#    print(row['FIRST'])
    if (row['FIRST'] >=0 and row['FIRST'] <= 4):
  #      print("I am in night")
        return "Night"
    elif (row['FIRST'] >4 and row['FIRST'] <= 8):
 #       print("I am in early morning")
        return "Early Morning"
    elif (row['FIRST'] >8 and row['FIRST'] < 12):
        return "Morning"
    elif (row['FIRST'] >=12 and row['FIRST'] < 17):
        return "Afternoon"
    elif (row['FIRST'] >=17 and row['FIRST'] < 21):
        return "Evening"
    else: return "Night"
    return

# %%
grouped_time["TIME_BINS"] = grouped_time.apply(make_time_bins, axis=1)

grouped_time.head()
# Out:
#   STATION DIVISION       DATE      TIME     DESC           Date_Time  \
# 1   59 ST      BMT 2019-05-11  04:00:00  REGULAR 2019-05-11 04:00:00
# 2   59 ST      BMT 2019-05-11  08:00:00  REGULAR 2019-05-11 08:00:00
# 3   59 ST      BMT 2019-05-11  12:00:00  REGULAR 2019-05-11 12:00:00
# 4   59 ST      BMT 2019-05-11  16:00:00  REGULAR 2019-05-11 16:00:00
# 5   59 ST      BMT 2019-05-11  20:00:00  REGULAR 2019-05-11 20:00:00
#
#                Turnstile  Week_Day  TOTAL_TRAFFIC  FIRST      TIME_BINS
# 1  A002R05102-00-0059 ST  Saturday           31.0      4          Night
# 2  A002R05102-00-0059 ST  Saturday           51.0      8  Early Morning
# 3  A002R05102-00-0059 ST  Saturday          144.0     12      Afternoon
# 4  A002R05102-00-0059 ST  Saturday          282.0     16      Afternoon
# 5  A002R05102-00-0059 ST  Saturday          339.0     20        Evening

# %%
Top10_stations = grouped_time[grouped_time['STATION'].isin(Top10)]
Top10_station_slot = Top10_stations.groupby(['STATION','TIME_BINS']).TOTAL_TRAFFIC.sum().reset_index()

# %%
timeaxis_list = ["Early Morning", "Morning", "Afternoon", "Evening", "Night"]

for stations in Top10:
    station = Top10_station_slot[Top10_station_slot['STATION'] == stations]
#    print(station)
#    station.set_index('TIME_BINS').loc[timeaxis_list]
#    ax = df.set_index(field).loc[day_order].plot(kind="bar", legend=False)
    station = station.set_index('TIME_BINS').loc[timeaxis_list]
    plt.plot(station['TOTAL_TRAFFIC'],label = stations)
#    plt.xticks(timeaxis_list)
    
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
#df.set_index(field).loc[day_order]
plt.xlabel("Stations", fontsize=18)
plt.ylabel("Average Income (Thousands)",fontsize=18)
plt.title("Top 10 Stations with Highest Incomes",fontsize=27)
plt.rcParams.update({'font.size': 10})
plt.legend()
plt.show()

# %%
top103sorted = Top10_station_slot.sort_values("TOTAL_TRAFFIC", ascending=False)

# %%
#Top10_station_slot
mask = top103sorted["TIME_BINS"] == "Morning"
top103sorted[mask].reset_index()
# Out:
#    index          STATION TIME_BINS  TOTAL_TRAFFIC
# 0     38        FULTON ST   Morning      2349302.0
# 1      8   14 ST-UNION SQ   Morning      1731450.0
# 2     23   34 ST-PENN STA   Morning      1497973.0
# 3     43  GRD CNTRL-42 ST   Morning      1458470.0
# 4      3           125 ST   Morning       985742.0
# 5     28  42 ST-PORT AUTH   Morning       835653.0
# 6     13            23 ST   Morning       743232.0
# 7     33            86 ST   Morning       557980.0
# 8     48   TIMES SQ-42 ST   Morning        61284.0
# 9     18  34 ST-HERALD SQ   Morning        40235.0

# %%
mask = top103sorted["TIME_BINS"] == "Afternoon"
top103sorted[mask].reset_index()
# Out:
#    index          STATION  TIME_BINS  TOTAL_TRAFFIC
# 0     20   34 ST-PENN STA  Afternoon      8004187.0
# 1     15  34 ST-HERALD SQ  Afternoon      6569773.0
# 2     45   TIMES SQ-42 ST  Afternoon      5406785.0
# 3     40  GRD CNTRL-42 ST  Afternoon      5239256.0
# 4     10            23 ST  Afternoon      4860277.0
# 5     30            86 ST  Afternoon      4472959.0
# 6     25  42 ST-PORT AUTH  Afternoon      3974342.0
# 7      0           125 ST  Afternoon      3134700.0
# 8      5   14 ST-UNION SQ  Afternoon      2752343.0
# 9     35        FULTON ST  Afternoon      2498333.0

# %%
mask = top103sorted["TIME_BINS"] == "Evening"
top103sorted[mask].reset_index()
# Out:
#    index          STATION TIME_BINS  TOTAL_TRAFFIC
# 0     22   34 ST-PENN STA   Evening      5947600.0
# 1     47   TIMES SQ-42 ST   Evening      4158460.0
# 2     12            23 ST   Evening      4056645.0
# 3     17  34 ST-HERALD SQ   Evening      3946977.0
# 4     42  GRD CNTRL-42 ST   Evening      3903242.0
# 5      7   14 ST-UNION SQ   Evening      3462366.0
# 6     37        FULTON ST   Evening      3210834.0
# 7     32            86 ST   Evening      3009873.0
# 8     27  42 ST-PORT AUTH   Evening      2931840.0
# 9      2           125 ST   Evening      2691629.0

# %%
def make_time_bins1(row):
#    print(row['FIRST'])
    #if (row['FIRST'] >=0 and row['FIRST'] <= 4):
  #      print("I am in night")
     #   return "Night"
    if (row['FIRST'] >=4 and row['FIRST'] <= 12):
 #       print("I am in early morning")
        return "Pre-Noon"
    elif (row['FIRST'] >12 and row['FIRST'] <= 20):
        return "Post-Noon"
    #elif (row['FIRST'] >=12 and row['FIRST'] < 17):
     #   return "Afternoon"
    #elif (row['FIRST'] >=17 and row['FIRST'] < 21):
     #   return "Evening"
    #else: return "Night"
    return

# %%
grouped_time["TIME_BINS1"] = grouped_time.apply(make_time_bins1, axis=1)

grouped_time.head()
# Out:
#   STATION DIVISION       DATE      TIME     DESC           Date_Time  \
# 1   59 ST      BMT 2019-05-11  04:00:00  REGULAR 2019-05-11 04:00:00
# 2   59 ST      BMT 2019-05-11  08:00:00  REGULAR 2019-05-11 08:00:00
# 3   59 ST      BMT 2019-05-11  12:00:00  REGULAR 2019-05-11 12:00:00
# 4   59 ST      BMT 2019-05-11  16:00:00  REGULAR 2019-05-11 16:00:00
# 5   59 ST      BMT 2019-05-11  20:00:00  REGULAR 2019-05-11 20:00:00
#
#                Turnstile  Week_Day  TOTAL_TRAFFIC  FIRST      TIME_BINS  \
# 1  A002R05102-00-0059 ST  Saturday           31.0      4          Night
# 2  A002R05102-00-0059 ST  Saturday           51.0      8  Early Morning
# 3  A002R05102-00-0059 ST  Saturday          144.0     12      Afternoon
# 4  A002R05102-00-0059 ST  Saturday          282.0     16      Afternoon
# 5  A002R05102-00-0059 ST  Saturday          339.0     20        Evening
#
#   TIME_BINS1
# 1   Pre-Noon
# 2   Pre-Noon
# 3   Pre-Noon
# 4  Post-Noon
# 5  Post-Noon

# %%
Top10_stations = grouped_time[grouped_time['STATION'].isin(Top10)]
Top10_station_slot1 = Top10_stations.groupby(['STATION','TIME_BINS1']).TOTAL_TRAFFIC.sum().reset_index()

# %%
timeaxis_list = ["Pre-Noon","Post-Noon"]

for stations in Top10:
    station = Top10_station_slot1[Top10_station_slot1['STATION'] == stations]
#    print(station)
#    station.set_index('TIME_BINS').loc[timeaxis_list]
#    ax = df.set_index(field).loc[day_order].plot(kind="bar", legend=False)
    station = station.set_index('TIME_BINS1').loc[timeaxis_list]
    plt.plot(station['TOTAL_TRAFFIC'],label = stations)
#    plt.xticks(timeaxis_list)
    
#plt.ylim(32500000000,40700000000)
#plt.ylim(400000000,405000000)
#df.set_index(field).loc[day_order]
plt.xlabel("Time of the Day", fontsize=18)
plt.ylabel("Total Traffic (millions)",fontsize=18)
plt.title("Top 10 Stations Traffic Before & After Noon",fontsize=27)
plt.rcParams.update({'font.size': 10})
plt.legend()
plt.show()

# %%
top10sorted = Top10_station_slot1.sort_values("TOTAL_TRAFFIC", ascending=False)
top10sorted
# Out:
#             STATION TIME_BINS1  TOTAL_TRAFFIC
# 8    34 ST-PENN STA  Post-Noon     10136510.0
# 9    34 ST-PENN STA   Pre-Noon      7349932.0
# 16  GRD CNTRL-42 ST  Post-Noon      7320999.0
# 6   34 ST-HERALD SQ  Post-Noon      7297737.0
# 4             23 ST  Post-Noon      6982263.0
# 18   TIMES SQ-42 ST  Post-Noon      6836827.0
# 2    14 ST-UNION SQ  Post-Noon      6204993.0
# 12            86 ST  Post-Noon      5616531.0
# 14        FULTON ST  Post-Noon      5579196.0
# 10  42 ST-PORT AUTH  Post-Noon      5137716.0
# 0            125 ST  Post-Noon      4782608.0
# 7   34 ST-HERALD SQ   Pre-Noon      4615019.0
# 17  GRD CNTRL-42 ST   Pre-Noon      4581841.0
# 19   TIMES SQ-42 ST   Pre-Noon      4094223.0
# 11  42 ST-PORT AUTH   Pre-Noon      4066773.0
# 13            86 ST   Pre-Noon      3374935.0
# 5             23 ST   Pre-Noon      3322651.0
# 15        FULTON ST   Pre-Noon      2835220.0
# 1            125 ST   Pre-Noon      2802940.0
# 3    14 ST-UNION SQ   Pre-Noon      1939674.0

# %%
mask = top10sorted["TIME_BINS1"] == "Pre-Noon"
top10sorted[mask].reset_index()
# Out:
#    index          STATION TIME_BINS1  TOTAL_TRAFFIC
# 0      9   34 ST-PENN STA   Pre-Noon      7349932.0
# 1      7  34 ST-HERALD SQ   Pre-Noon      4615019.0
# 2     17  GRD CNTRL-42 ST   Pre-Noon      4581841.0
# 3     19   TIMES SQ-42 ST   Pre-Noon      4094223.0
# 4     11  42 ST-PORT AUTH   Pre-Noon      4066773.0
# 5     13            86 ST   Pre-Noon      3374935.0
# 6      5            23 ST   Pre-Noon      3322651.0
# 7     15        FULTON ST   Pre-Noon      2835220.0
# 8      1           125 ST   Pre-Noon      2802940.0
# 9      3   14 ST-UNION SQ   Pre-Noon      1939674.0

# %%
mask1 = top10sorted["TIME_BINS1"] == "Post-Noon"
top10sorted[mask1].reset_index()
# Out:
#    index          STATION TIME_BINS1  TOTAL_TRAFFIC
# 0      8   34 ST-PENN STA  Post-Noon     10136510.0
# 1     16  GRD CNTRL-42 ST  Post-Noon      7320999.0
# 2      6  34 ST-HERALD SQ  Post-Noon      7297737.0
# 3      4            23 ST  Post-Noon      6982263.0
# 4     18   TIMES SQ-42 ST  Post-Noon      6836827.0
# 5      2   14 ST-UNION SQ  Post-Noon      6204993.0
# 6     12            86 ST  Post-Noon      5616531.0
# 7     14        FULTON ST  Post-Noon      5579196.0
# 8     10  42 ST-PORT AUTH  Post-Noon      5137716.0
# 9      0           125 ST  Post-Noon      4782608.0
